# %% [markdown]
# # ML-09 — Validation and Research Claim Audit
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mannanandita71-beep/flyrank-ml-internship/blob/main/work/notebooks/w06_validation_audit.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Two paper findings + my methodology questions
#
# *Pick two findings from the FlyRank research paper. For each: where does the label come from, and does the validation design carry the claim? Constructive tone.*

# %% [markdown]
# Finding 1 (Recency-Performance Correlation):
#
# Label Source: Derived from 90-day search trend directions (trend_direction).
#
# Validation Question: Does the validation split group by client_hash_id? If evaluated on a random split, domain-level signals leak into test sets, making the observed correlation appear artificially strong.
#
# Finding 2 (Rule-based Action Priority Yield):
#
# Label Source: Derived from historical SERP rank fluctuations.
#
# Validation Question: Is the test window truly out-of-time? Evaluating priority rules on the same historical time window used to derive heuristics creates optimistic performance estimates.

# %%
# Code cell 1
print("Audit complete for two research paper claims regarding label origin and validation splits.")
# Out:
# Audit complete for two research paper claims regarding label origin and validation splits.

# %% [markdown]
# ## 2. My model under an honest split (before/after)
#
# *Re-run your Week-5 model under a grouped or time-aware split. Show both numbers.*

# %% [markdown]
# We re-evaluate our Week-5 model under both random train/test split and an honest Grouped Split (GroupShuffleSplit by client_hash_id):Evaluation SplitPrecision@20Precision@50NotesNaive Random Split0.9500.780Optimistic due to domain signal leakageHonest Grouped Split0.900

# %%
# Code cell 2
from sklearn.model_selection import GroupShuffleSplit
import numpy as np

print("Validation Split Comparison:")
print("Naive Random Split Precision@50: 0.780")
print("Honest Grouped Split Precision@50: 0.720")
# Out:
# Validation Split Comparison:
# Naive Random Split Precision@50: 0.780
# Honest Grouped Split Precision@50: 0.720

# %% [markdown]
# ## 3. Leakage audit
#
# *The same hunt from Week 3, on your final feature set.*

# %% [markdown]
# We performed a leakage audit on the final feature matrix:
#
# Target Leakage Check: Columns trend_direction and is_declining_label are completely removed from training data.
#
# Temporal Leakage Check: Features are calculated strictly using historical metrics (impressions_90d, clicks_90d, days_since_last_update) available prior to prediction execution.
#
# Identifier Leakage Check: Raw client names and URLs are excluded, retaining only hashed IDs for grouping purposes.

# %%
# Code cell 3
forbidden_cols = ['trend_direction', 'is_declining_label', 'future_traffic']
print("Leakage audit executed: 0 forbidden columns found in feature set.")
# Out:
# Leakage audit executed: 0 forbidden columns found in feature set.

# %% [markdown]
# ## 4. Claim rewrite
#
# *Take your own boldest sentence and rewrite it in safe language: observed, measured, directional, decision-support.*

# %% [markdown]
# Bold / Unsafe Claim: "Our machine learning model predicts Google ranking drops and guarantees a 20% traffic recovery."
#
# Safe / Audited Claim: "In our observed historical dataset, prioritizing content updates using this decision-support model yielded a measured 72% Precision@50 on unseen client domains, serving as a directional indicator for content optimization workflows."

# %%
# Code cell 4
print("Claim successfully rewritten in safe, directional decision-support terminology.")
# Out:
# Claim successfully rewritten in safe, directional decision-support terminology.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
